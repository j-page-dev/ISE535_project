# %%
from position_dataframes import rb_games, wr_games, qb_games, games, playerComparison

# %%
rb_games('Antonio Gibson')
# Out:
#       Unnamed: 0 Team  Opp  ... Tot_lag3 Pass_lag3  Russ_lag3
# 235          235  WAS  CAR  ...    387.0     291.0       96.0
# 1075        1075  WAS  PIT  ...    324.0     185.0      139.0
# 1658        1658  WAS  DAL  ...    222.0     103.0      119.0
# 1817        1817  WAS  CIN  ...    398.0     316.0       82.0
# 2207        2207  WAS  DET  ...    388.0     322.0       66.0
# 2470        2470  WAS  NYG  ...    337.0     251.0       86.0
# 3165        3165  WAS  DAL  ...    508.0     201.0      307.0
# 3397        3397  WAS  NYG  ...    420.0     327.0       93.0
# 3617        3617  WAS  LAR  ...    363.0     242.0      121.0
# 3954        3954  WAS  BAL  ...    306.0     168.0      138.0
# 4374        4374  WAS  CLE  ...    438.0     315.0      123.0
# 4684        4684  WAS  ARI  ...    424.0     311.0      113.0
# 5033        5033  WAS  PHI  ...    311.0     257.0       54.0
#
# [13 rows x 29 columns]

# %%
wr_games('Mike Evans')
# Out:
#       Unnamed: 0 Team  Opp  ... Tot_lag3 Pass_lag3  Russ_lag3
# 283          283  TAM  DET  ...    389.0     249.0      140.0
# 551          551  TAM  ATL  ...    243.0     203.0       40.0
# 1027        1027  TAM  MIN  ...    376.0     196.0      180.0
# 1646        1646  TAM  KAN  ...    221.0     128.0       93.0
# 1708        1708  TAM  LAR  ...    279.0     230.0       49.0
# 2065        2065  TAM  CAR  ...    415.0     277.0      138.0
# 2489        2489  TAM  NOR  ...    350.0     239.0      111.0
# 2616        2616  TAM  NYG  ...    402.0     276.0      126.0
# 2977        2977  TAM  LVR  ...    406.0     156.0      250.0
# 3414        3414  TAM  GNB  ...    307.0     218.0       89.0
# 3779        3779  TAM  CHI  ...    295.0     220.0       75.0
# 3863        3863  TAM  LAC  ...    295.0     173.0      122.0
# 4320        4320  TAM  DEN  ...    465.0     359.0      106.0
# 4691        4691  TAM  CAR  ...    379.0     264.0      115.0
# 4930        4930  TAM  NOR  ...    320.0     246.0       74.0
#
# [15 rows x 29 columns]

# %%
qb_games('Aaron Rodgers')
# Out:
#       Unnamed: 0 Team  Opp  ... Tot_lag3 Pass_lag3  Russ_lag3
# 245          245  GNB  TEN  ...    458.0     340.0      118.0
# 638          638  GNB  CAR  ...    185.0     145.0       40.0
# 909          909  GNB  DET  ...    374.0     258.0      116.0
# 1115        1115  GNB  PHI  ...    382.0     231.0      151.0
# 1512        1512  GNB  CHI  ...    394.0     272.0      122.0
# 1925        1925  GNB  IND  ...    326.0     297.0       29.0
# 2128        2128  GNB  JAX  ...    403.0     223.0      180.0
# 2590        2590  GNB  SFO  ...    311.0     198.0      113.0
# 2662        2662  GNB  MIN  ...    386.0     290.0       96.0
# 3099        3099  GNB  HOU  ...    410.0     248.0      162.0
# 3243        3243  GNB  TAM  ...    226.0     184.0       42.0
# 3791        3791  GNB  ATL  ...    383.0     299.0       84.0
# 4204        4204  GNB  NOR  ...    316.0     189.0      127.0
# 4699        4699  GNB  DET  ...    432.0     312.0      120.0
# 4852        4852  GNB  MIN  ...    383.0     199.0      184.0
#
# [15 rows x 29 columns]

# %%
games('Mahomes')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#             Unnamed: 0 Team  Opp  ... Tot_lag3 Pass_lag3  Russ_lag3
# Date                              ...
# 2020-09-10        5137  KAN  HOU  ...    435.0     329.0      106.0
# 2020-09-20        4644  KAN  LAC  ...    336.0     174.0      162.0
# 2020-09-28        4139  KAN  BAL  ...    220.0     188.0       32.0
# 2020-10-05        3812  KAN  NWE  ...    269.0     182.0       87.0
# 2020-10-11        3552  KAN  LVR  ...    424.0     312.0      112.0
# 2020-10-19        3207  KAN  BUF  ...    478.0     311.0      167.0
# 2020-10-25        3035  KAN  DEN  ...    353.0     285.0       68.0
# 2020-11-01        2740  KAN  NYJ  ...    496.0     369.0      127.0
# 2020-11-08        2418  KAN  CAR  ...    261.0     198.0       63.0
# 2020-11-22        1894  KAN  LVR  ...    223.0     122.0      101.0
# 2020-11-29        1629  KAN  TAM  ...    420.0     282.0      138.0
# 2020-12-06        1345  KAN  DEN  ...    357.0     154.0      203.0
# 2020-12-13         744  KAN  MIA  ...    459.0     270.0      189.0
# 2020-12-20         531  KAN  NOR  ...    112.0      12.0      100.0
# 2020-12-27         237  KAN  ATL  ...    424.0     217.0      207.0
#
# [15 rows x 28 columns]

# %%
# player comparison example
input1 = 'Adam Thielen'
input2 = 'DeAndre Hopkins'

p1, p2 = playerComparison(input1, input2)
print(input1)
print(p1)

print(" ")

print(input2)
print(p2)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# Adam Thielen
#             Unnamed: 0 Team  Opp  ... Tot_lag3 Pass_lag3  Russ_lag3
# Date                              ...
# 2020-12-25         344  MIN  NOR  ...    332.0     262.0       70.0
# 2020-12-20         525  MIN  CHI  ...    393.0     211.0      182.0
# 2020-12-13         888  MIN  TAM  ...    187.0     122.0       65.0
# 2020-12-06        1311  MIN  JAX  ...    395.0     315.0       80.0
# 2020-11-22        1762  MIN  DAL  ...    397.0     189.0      208.0
# 2020-11-16        2008  MIN  CHI  ...    371.0     211.0      160.0
# 2020-11-08        2457  MIN  DET  ...    275.0     231.0       44.0
# 2020-11-01        2874  MIN  GNB  ...    327.0     249.0       78.0
# 2020-10-18        3265  MIN  ATL  ...    437.0     307.0      130.0
# 2020-10-11        3724  MIN  SEA  ...    464.0     397.0       67.0
# 2020-10-04        3910  MIN  HOU  ...    369.0     203.0      166.0
# 2020-09-27        4223  MIN  TEN  ...    401.0     165.0      236.0
# 2020-09-20        4606  MIN  IND  ...    283.0     230.0       53.0
# 2020-09-13        5041  MIN  GNB  ...    356.0     248.0      108.0
#
# [14 rows x 28 columns]
#
# DeAndre Hopkins
#             Unnamed: 0 Team  Opp  ... Tot_lag3 Pass_lag3  Russ_lag3
# Date                              ...
# 2020-12-26         310  ARI  SFO  ...    449.0     368.0       81.0
# 2020-12-20         371  ARI  PHI  ...    301.0     225.0       76.0
# 2020-12-13         810  ARI  NYG  ...    346.0     190.0      156.0
# 2020-12-06        1176  ARI  LAR  ...    333.0     220.0      113.0
# 2020-11-29        1593  ARI  NWE  ...    322.0     257.0       65.0
# 2020-11-19        1989  ARI  SEA  ...    351.0     299.0       52.0
# 2020-11-15        2031  ARI  BUF  ...    191.0      91.0      100.0
# 2020-11-08        2566  ARI  MIA  ...    259.0     128.0      131.0
# 2020-10-25        3160  ARI  SEA  ...    522.0     461.0       61.0
# 2020-10-19        3222  ARI  DAL  ...    412.0     295.0      117.0
# 2020-10-11        3543  ARI  NYJ  ...    359.0     177.0      182.0
# 2020-10-04        3949  ARI  CAR  ...    372.0     239.0      133.0
# 2020-09-27        4351  ARI  DET  ...    508.0     383.0      125.0
# 2020-09-20        4653  ARI  WAS  ...    216.0      98.0      118.0
# 2020-09-13        5047  ARI  SFO  ...    395.0     323.0       72.0
#
# [15 rows x 28 columns]

# %%
def lineupVisualizer(qb, rb1, rb2, wr1, wr2, wr3):
  py.plot(games(qb).FD_points, label = qb)
  py.plot(games(rb1).FD_points, label = rb1)
  py.plot(games(rb2).FD_points, label = rb2)
  py.plot(games(wr1).FD_points, label = wr1)
  py.plot(games(wr2).FD_points, label = wr2)
  py.plot(games(wr3).FD_points, label = wr3)
  py.legend()
  py.title('Lineup, Fantasy Point History')
  py.show()

  avgs = [games(qb).FD_points.mean(), games(rb1).FD_points.mean(), games(rb2).FD_points.mean(),
          games(wr1).FD_points.mean(), games(wr2).FD_points.mean(), games(wr3).FD_points.mean()]

  sds = [games(qb).FD_points.std(), games(rb1).FD_points.std(), games(rb2).FD_points.std(),
          games(wr1).FD_points.std(), games(wr2).FD_points.std(), games(wr3).FD_points.std()]



  py.bar([qb, rb1, rb2, wr1, wr2, wr3], height = avgs)
  py.bar([qb, rb1, rb2, wr1, wr2, wr3], height = sds)
  py.title('Lineup, Average Fantasy Points (SD in orange)')
  py.show()

# Lineup example
qb = 'Patrick Mahomes'
rb1 = 'Derrick Henry'
rb2 = 'Jonathan Taylor'
wr1 = 'Tyreek Hill'
wr2 = 'Adam Thielen'
wr3 = 'DeAndre Hopkins'

lineupVisualizer(qb, rb1, rb2, wr1, wr2, wr3)

# note the quarterback has a high avg and low sds. 
# sds can be used in decision making as consistency is desired
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
